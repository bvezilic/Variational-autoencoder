# %%
# Fix PYTHONPATH to point `vae` directory as root
import sys
from pathlib import Path

cwd = Path(".").resolve()
print(f"Current directory: {cwd.resolve()}")
vae_rootdir = cwd.parent
print(f"VAE root directory: {vae_rootdir}")

sys.path.append(str(vae_rootdir))

# %% [markdown]
# # Variational Autoecoder

# %% [markdown]
# Now we can do the rest of the imports

# %%
# %matplotlib inline
import json

import numpy as np
import matplotlib.pyplot as plt
from torch.optim import Adam
from torch.utils.data.dataloader import DataLoader
from torchvision.datasets import MNIST
from torchvision.transforms import ToTensor

from vae.callbacks import PlotCallback
from vae.loss import loss_criterion
from vae.model import VAE
from vae.train import Trainer
from vae.utils import load_model, save_model
from config import *

# %% [markdown]
# Let's set training and model parameters

# %%
# Training params
batch_size = 64
lr = 0.001
device = "cuda"

# Model params
input_size = 784
hidden_size = 512
latent_size = 10

# %% [markdown]
# Load data set and create data loader

# %%
# Load data set
dataset = MNIST(DATA_DIR, transform=ToTensor(), download=True)

# Create data loader
data_loader = DataLoader(dataset=dataset, batch_size=batch_size)

# %% [markdown]
# Initialize model and optimizer

# %%
# Initialize model
model = VAE(input_size, hidden_size, latent_size)

# Initialize optimizer
optimizer = Adam(model.parameters(), lr=lr)

# %% [markdown]
# Now that we have our dataset, model and optimizer ready, only that's left is to initialize it in `Trainer` and run training.

# %%
# Initialize trainer
trainer = Trainer(model=model,
                  data_loader=data_loader,
                  optimizer=optimizer,
                  device=device)

# %% [markdown]
# Run training for number of epochs.

# %%
losses = trainer.run_train_loop(epochs=20)

# %% [markdown]
# Plot losses during training

# %%
plt.plot(np.arange(len(losses)), losses)
plt.title("Training")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# Even though it's used as a callback to plot samples during training, it can be used to generate samples aside from the train loop.

# %%
plot_cb = PlotCallback()
for _ in range(2):
    plot_cb(trainer)
